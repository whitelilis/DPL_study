# %%
import read_symbol_df

dfs = read_symbol_df.tick_df(["/tmp/test.tick", "rb2305"])

r = read_symbol_df.sim(dfs[0])
r
# Out:
#  0  rb2305 volume:  507400, step     0.000 range          0
# /Users/liuzhe/github/DPL_study/nbs/read_symbol_df.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ret.loc[:,'isb'] = ret.apply(lambda row: row['p'] == row['b1'], axis=1)
# /Users/liuzhe/github/DPL_study/nbs/read_symbol_df.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ret.loc[:,'dv'] = ret.v.diff()
#               p       v      a1  av1      b1  bv1    isb      dv
# ...
